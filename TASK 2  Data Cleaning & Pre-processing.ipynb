# %% [markdown]
# #                                                 "Medical Treatment Outcomes and Financial Analysis"

# %% [markdown]
# ### 📍 TASK 2: Data Cleaning & Pre-processing
# #### Handling missing data, duplicates, formatting, derived features, and transformation.

# %% [markdown]
# #### Data Pre-processing

# %% [markdown]
# #### ● Perform all necessary cleaning steps such as :

# %% [markdown]
#      1. Handling missing values
#      2. Removing duplicates
#      3. Correcting data types
#      4. Creating derived columns
#      5. Filtering or aggregating data

# %% [markdown]
# ### 1️⃣ Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2️⃣ Reading the Dataset

# %%
df = pd.read_csv(r"C:\Users\Surface Pro\Downloads\healthcare_dataset.csv")

# %% [markdown]
# ### ➤ Loading the First 5 Columns of HealthCare Dataset

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ### 3️⃣ Data Pre-processing

# %% [markdown]
# ### ⏳ 1. Handling missing values

# %% [markdown]
# 🔑 Checking For Missing Value :
#        Summing up to Find Total Number of Missing Value in this Dataset.
#
# 🔑 Inference :
#        In this Data-Set, there is NO Missing Value. So, no action taken.

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# ### ⏳ 2. Removing duplicates

# %% [markdown]
# #### 🔑 A . Finding the Total Number of Duplicated Data in the Health-Care DataSet

# %%
df.duplicated().sum()
# Out:
# 534

# %% [markdown]
# #### 🔑 B. Removing the Duplicated Data

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()   # Checking the Duplicated Data is Removed
# Out:
# 0

# %% [markdown]
# ### ⏳ 3. Formating Data

# %% [markdown]
# ### 🔑 A. Strip whitespace and convert to title case from Name Column

# %%
df["Name"] = df["Name"].str.strip().str.title()  # Name column

# %%
df.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30   Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62   Male         A+           Obesity        2019-08-20
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons and Miller         Blue Cross    18856.281306
# 1  Samantha Davies          Kim Inc           Medicare    33643.327287
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive

# %% [markdown]
# ### 🔑 B. Strip whitespace and convert to title case from Hospital column

# %%
df['Hospital'] = df['Hospital'].str.strip().str.rstrip('')

# %% [markdown]
# ### 🔑 C. Re-arranging 'and Montes Graves, Thomas' to 'Thomas and Montes Graves'

# %%
# Targeting rows where the name ends with ", Thomas" and reformatting
df['Hospital'] = df['Hospital'].str.replace(r',\s*Thomas$', '', regex=True).str.strip()
df['Hospital'] = df['Hospital'].apply(lambda x: 'Thomas ' + x if 'Montes Graves' in x else x)

# %% [markdown]
# ### 🔑 D. Remove 'and' from the Begining from Hospital Column

# %%
df['Hospital'] = df['Hospital'].str.lstrip("and ")

# %%
df['Hospital'] = df['Hospital'].str.lstrip("And ")

# %% [markdown]
# ### 🔑 E. Remove 'and' from the End of Hospital Column

# %%
df['Hospital'] = df['Hospital'].str.rstrip(" and")
df.head(3)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30    Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62    Male         A+           Obesity        2019-08-20
# 2    Danny Smith   76  Female         A-           Obesity        2022-09-22
#
#              Doctor         Hospital Insurance Provider  Billing Amount  \
# 0     Matthew Smith  Sons and Miller         Blue Cross    18856.281306
# 1   Samantha Davies          Kim Inc           Medicare    33643.327287
# 2  Tiffany Mitchell         Cook PLC              Aetna    27955.096079
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive
# 2          205      Emergency     2022-10-07      Aspirin        Normal

# %% [markdown]
# ### ⏳ 4. Correcting Data Type

# %% [markdown]
# ### 🔑 A. # Standardize Insurance Provider

# %%
df['Insurance Provider'] = df['Insurance Provider'].str.replace('UnitedHealthcare', 'United Healthcare', regex=False) 
# Standardize Insurance Provider names

# %%
df.head(7)
# Out:
#              Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0   Bobby Jackson   30    Male         B-            Cancer        2024-01-31
# 1    Leslie Terry   62    Male         A+           Obesity        2019-08-20
# 2     Danny Smith   76  Female         A-           Obesity        2022-09-22
# 3    Andrew Watts   28  Female         O+          Diabetes        2020-11-18
# 4   Adrienne Bell   43  Female        AB+            Cancer        2022-09-19
# 5   Emily Johnson   36    Male         A+            Asthma        2023-12-20
# 6  Edward Edwards   21  Female        AB-          Diabetes        2020-11-03
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
# 5     Taylor Newton              Nunez-Humphrey  United Healthcare
# 6       Kelly Olson              Group Middleto           Medicare
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
# 5    48145.110951          389         Urgent     2023-12-24    Ibuprofen
# 6    19580.872345          389      Emergency     2020-11-15  Paracetamol
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal
# 5        Normal
# 6  Inconclusive

# %% [markdown]
# ### 🔑 B. Converting Strings to Dates

# %% [markdown]
# #### ▶️ B1. Converting String to Date Formmat

# %%
df['Date of Admission'] = pd.to_datetime(df['Date of Admission'], errors='coerce')
df['Discharge Date'] = pd.to_datetime(df['Discharge Date'], errors='coerce')

# %%
df.head(3)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30    Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62    Male         A+           Obesity        2019-08-20
# 2    Danny Smith   76  Female         A-           Obesity        2022-09-22
#
#              Doctor         Hospital Insurance Provider  Billing Amount  \
# 0     Matthew Smith  Sons and Miller         Blue Cross        18856.28
# 1   Samantha Davies          Kim Inc           Medicare        33643.33
# 2  Tiffany Mitchell         Cook PLC              Aetna        27955.10
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent     2024-02-02  Paracetamol        Normal
# 1          265      Emergency     2019-08-26    Ibuprofen  Inconclusive
# 2          205      Emergency     2022-10-07      Aspirin        Normal

# %% [markdown]
# ### ▶️ B2. Rounding off Float Decimal Point into 2

# %%
df['Billing Amount'] = df['Billing Amount'].round(2)
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30    Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62    Male         A+           Obesity        2019-08-20
# 2    Danny Smith   76  Female         A-           Obesity        2022-09-22
# 3   Andrew Watts   28  Female         O+          Diabetes        2020-11-18
# 4  Adrienne Bell   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0        18856.28          328         Urgent     2024-02-02  Paracetamol
# 1        33643.33          265      Emergency     2019-08-26    Ibuprofen
# 2        27955.10          205      Emergency     2022-10-07      Aspirin
# 3        37909.78          450       Elective     2020-12-18    Ibuprofen
# 4        14238.32          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %% [markdown]
# ### ⏳ 5. Creating Derived Column

# %% [markdown]
# ### 🔑 A. Calculate Length of Stay

# %%
 df['Length of Stay'] = (df['Discharge Date'] - df['Date of Admission']).dt.days

# %%
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                   Hospital  \
# 0            2024-01-31     Matthew Smith            Sons And Miller
# 1            2019-08-20   Samantha Davies                    Kim Inc
# 2            2022-09-22  Tiffany Mitchell                   Cook Plc
# 3            2020-11-18       Kevin Wells  Hernandez Rogers And Vang
# 4            2022-09-19    Kathleen Hanna                White-White
# ...                 ...               ...                        ...
# 55495        2020-08-16     Joshua Jarvis              Jones-Thompso
# 55496        2020-01-23   Taylor Sullivan               Tucker-Moyer
# 55497        2020-07-13    Joe Jacobs DVM    Mahoney Johnson Vasquez
# 55498        2019-05-25    Kimberly Curry    Jackson Todd And Castro
# 55499        2024-04-02     Dennis Warren               Henry Sons A
#
#       Insurance Provider  Billing Amount Admission Type Discharge Date  \
# 0             Blue Cross        18856.28         Urgent     2024-02-02
# 1               Medicare        33643.33      Emergency     2019-08-26
# 2                  Aetna        27955.10      Emergency     2022-10-07
# 3               Medicare        37909.78       Elective     2020-12-18
# 4                  Aetna        14238.32         Urgent     2022-10-09
# ...                  ...             ...            ...            ...
# 55495         Blue Cross         2650.71       Elective     2020-09-15
# 55496              Cigna        31457.80       Elective     2020-02-01
# 55497  United Healthcare        27620.76         Urgent     2020-08-10
# 55498           Medicare        32451.09       Elective     2019-05-31
# 55499              Aetna         4010.13         Urgent     2024-04-29
#
#         Medication  Test Results  Length of Stay
# 0      Paracetamol        Normal               2
# 1        Ibuprofen  Inconclusive               6
# 2          Aspirin        Normal              15
# 3        Ibuprofen      Abnormal              30
# 4       Penicillin      Abnormal              20
# ...            ...           ...             ...
# 55495   Penicillin      Abnormal              30
# 55496      Aspirin        Normal               9
# 55497    Ibuprofen      Abnormal              28
# 55498    Ibuprofen      Abnormal               6
# 55499    Ibuprofen      Abnormal              27
#
# [54966 rows x 15 columns]

# %% [markdown]
# ### 📩 Saving the Cleaned Data-Set:

# %%
df.to_csv("cleaned_HealthCareData.csv", index=False)

# %% [markdown]
# ### ⏳ 5️⃣ Filtering or aggregating data

# %% [markdown]
# ### 🔑 A. Filtering data based on Length of Stay (25 days and above)

# %%
df_long_stay = df[df['Length of Stay'] >= 25]

# %%
# Set 'Length of Stay' as the index
df_long_stay = df_long_stay.set_index('Length of Stay')
df_long_stay
# Out:
#                                Name  Age  Gender Blood Type Medical Condition  \
# Length of Stay
# 30                     Andrew Watts   28  Female         O+          Diabetes
# 30                 Christopher Berg   58  Female        AB-            Cancer
# 28                     Robert Bauer   68  Female        AB+            Asthma
# 25              Mrs. Jamie Campbell   38    Male        AB-           Obesity
# 29                  Kathryn Stewart   58  Female         O+         Arthritis
# ...                             ...  ...     ...        ...               ...
# 30                  Deborah Pearson   34    Male         A+           Obesity
# 26                     Gloria Bowen   57  Female         B-         Arthritis
# 30                Elizabeth Jackson   42  Female         O+            Asthma
# 28                     Heather Wang   38  Female         B+      Hypertension
# 27                     James Garcia   53  Female         O+         Arthritis
#
#                Date of Admission           Doctor                    Hospital  \
# Length of Stay
# 30                    2020-11-18      Kevin Wells  Hernandez Rogers and Vang,
# 30                    2021-05-23      Heather Day              Padilla-Walker
# 28                    2020-05-22  Theresa Freeman            Rivera-Gutierrez
# 25                    2020-03-08       Justin Kim  Torres, and Harrison Jones
# 29                    2022-05-12   Vanessa Newton                  Clark-Mayo
# ...                          ...              ...                         ...
# 30                    2022-01-05   David Williams                 Stone-Stout
# 26                    2022-07-23   Lucas Thompson              Group Gonzalez
# 30                    2020-08-16    Joshua Jarvis               Jones-Thompso
# 28                    2020-07-13   Joe Jacobs DVM    Mahoney Johnson Vasquez,
# 27                    2024-04-02    Dennis Warren                  Henry Sons
#
#                Insurance Provider  Billing Amount  Room Number Admission Type  \
# Length of Stay
# 30                       Medicare        37909.78          450       Elective
# 30              United Healthcare        19784.63          249       Elective
# 28              United Healthcare        33207.71          309         Urgent
# 25                          Cigna        17440.47          449         Urgent
# 29                          Aetna         5998.10          327         Urgent
# ...                           ...             ...          ...            ...
# 30                     Blue Cross        25051.50          144       Elective
# 26                       Medicare         3954.85          463      Emergency
# 30                     Blue Cross         2650.71          417       Elective
# 28              United Healthcare        27620.76          347         Urgent
# 27                          Aetna         4010.13          448         Urgent
#
#                Discharge Date   Medication  Test Results
# Length of Stay
# 30                 2020-12-18    Ibuprofen      Abnormal
# 30                 2021-06-22  Paracetamol  Inconclusive
# 28                 2020-06-19      Lipitor        Normal
# 25                 2020-04-02  Paracetamol      Abnormal
# 29                 2022-06-10      Lipitor  Inconclusive
# ...                       ...          ...           ...
# 30                 2022-02-04  Paracetamol        Normal
# 26                 2022-08-18      Aspirin      Abnormal
# 30                 2020-09-15   Penicillin      Abnormal
# 28                 2020-08-10    Ibuprofen      Abnormal
# 27                 2024-04-29    Ibuprofen      Abnormal
#
# [11043 rows x 15 columns]

# %% [markdown]
# ### 🔑 B. Aggregating Data

# %% [markdown]
# ### ▶️ B1. Finding Count of Gender

# %%
df.groupby('Gender').count()
# Out:
#          Name    Age  Blood Type  Medical Condition  Date of Admission  \
# Gender
# Female  27470  27470       27470              27470              27470
# Male    27496  27496       27496              27496              27496
#
#         Doctor  Hospital  Insurance Provider  Billing Amount  Room Number  \
# Gender
# Female   27470     27470               27470           27470        27470
# Male     27496     27496               27496           27496        27496
#
#         Admission Type  Discharge Date  Medication  Test Results  \
# Gender
# Female           27470           27470       27470         27470
# Male             27496           27496       27496         27496
#
#         Length of Stay
# Gender
# Female           27470
# Male             27496

# %% [markdown]
# ### ▶️ B2. Average of all medical condition

# %%
df.groupby('Medical Condition').mean(numeric_only = True)
# Out:
#                          Age  Billing Amount  Room Number  Length of Stay
# Medical Condition
# Arthritis          51.540464    25511.783245   300.800065       15.504231
# Asthma             51.595382    25633.461647   302.312259       15.677295
# Cancer             51.542123    25152.322927   302.123304       15.501204
# Diabetes           51.581814    25660.478627   301.383681       15.430664
# Hypertension       51.717954    25503.058694   299.587805       15.436236
# Obesity            51.233217    25804.361860   300.547999       15.447627

# %%
df.groupby('Medication').sum(numeric_only = True)
# Out:
#                 Age  Billing Amount  Room Number  Length of Stay
# Medication
# Aspirin      569280    2.811633e+08      3287735          170429
# Ibuprofen    568656    2.837849e+08      3328129          170366
# Lipitor      565953    2.796819e+08      3327699          170788
# Paracetamol  565494    2.802329e+08      3311691          170050
# Penicillin   563300    2.792054e+08      3296350          170301
